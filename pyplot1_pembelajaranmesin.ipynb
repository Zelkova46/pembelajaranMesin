# %% [markdown]
# ### Import Library

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Contoh 1

# %%
plt.plot([1,2,3,4,5,6,7, 10, 12, 13])
plt.ylabel('some numbers') # yang ini x nya automatis dari 1 sampe seterusnya y nya berdasarkan yang di kurung kotak
plt.show()

# %% [markdown]
# ### Contoh 2

# %%
plt.plot([1,2,3,4], [1,4,9, 16])

# %% [markdown]
# ## Contoh 3

# %%
plt.plot([1,2,3,4,5], [1,4,9, 16, 10])

# %%
x =[2,4,6,8,10]
y = [8,1,6,5,6]

plt.plot(x, y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Contoh 4

# %%
x1 = [6, 14, 16, 18, 20]
y1 = [12, 25, 34, 48, 69]
x2 = [6, 14, 16, 18, 30, 32]
y2 = [10, 23, 30, 43, 60, 62]

plt.plot(x1, y1, color = 'y')
plt.plot(x2, y2, color = 'r')

# %% [markdown]
# ## Contoh 5

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.axis([0, 6, 0 ,20])
plt.show()

# %% [markdown]
# ## Contoh 6

# %%
plt.plot([1.2,2,3.1, 4], [1,6.5, 9, 16.4], 'ro')
plt.plot([1,2,3,4], [1,4,9, 15])
plt.axis([0,6,0,20])
plt.show()

# %% [markdown]
# ## Contoh 7

# %%
import numpy as np

# evenly sampled time at 200 ms intervals
t = np.arange(0. , 5. , 0.2)

#red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
t
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8])

# %% [markdown]
# ## Contoh 8

# %%
data = {'a' : np.arange(50),
        'c' : np.random.randint(0,50, 50),
        'd' : np.random.randn(50)}
data ['b']= data ['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c = 'c' , s = 'd', data = data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %% [markdown]
# ## Contoh 9

# %%
x  = np.random.normal(size = 100)
plt.hist(x, bins = 10)
plt.show()

# %% [markdown]
# ## Contoh 10

# %%
names = ['group_a ', 'group_b', 'group_c']
values = [1, 10 , 100]

plt.figure(figsize = (9,3))

plt.subplot(131)
plt.bar(names, values)

plt.subplot(132)
plt.scatter(names, values)

plt.subplot(133)
plt.scatter(names, values)

plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# # LATIHAN BACA DATA

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataku = pd.read_csv('/content/merkhp.csv', sep = ';')

# %%
dataku
# Out:
#   KodeHP  Kamera  Harga
# 0     H1       8      7
# 1     H2       2      3
# 2     H3       6      7
# 3     H5       4      2
# 4     H7       7      8
# 5     H8       3      3

# %%
dataku['Kamera']
# Out:
# 0    8
# 1    2
# 2    6
# 3    4
# 4    7
# 5    3
# Name: Kamera, dtype: int64

# %%
dataku['Harga']
# Out:
# 0    7
# 1    3
# 2    7
# 3    2
# 4    8
# 5    3
# Name: Harga, dtype: int64

# %% [markdown]
# ## Konversi kolom menjadi list

# %%
L1 = dataku['Kamera'].values.tolist()
print(L1)
# Out:
# [8, 2, 6, 4, 7, 3]

# %%
L2 = dataku['Harga'].values.tolist()
print(L2)
# Out:
# [7, 3, 7, 2, 8, 3]

# %% [markdown]
# ## Buat ilustrasi pake pyplot

# %%
x = L1 #kAMERA
y = L2 #HARGA

plt.plot(x, y, 'ro')
plt.xlabel('Kamera')
plt.ylabel('Harga')
plt.axis([0,10,0,10])
plt.suptitle('Grafik Harga dan Kamera HP')
plt.show()
